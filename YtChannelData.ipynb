# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key="AIzaSyBdXMyRYQ-RkzKp3hEXFDWGoR7DRVfsNhg"
channel_id= "UCYaPuN9wvwP8gXUUezdvSUQ"

youtube=build('youtube', 'v3', developerKey= api_key)

# %% [markdown]
# # Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_id):
    request= youtube.channels().list(
        part= 'snippet, contentDetails, statistics',
        id= channel_id)
    response = request.execute()

    data= dict(Channel_name= response['items'][0]['snippet']['title'],
              Subscriber= response['items'][0]['statistics']['subscriberCount'],
              Views= response['items'][0]['statistics']['viewCount'],
              Total_videos= response['items'][0]['statistics']['videoCount'],
              playlist_id= response['items'][0]['contentDetails']['relatedPlaylists']['uploads'])

    return data

# %%
channel_stat=get_channel_stats(youtube, channel_id)

# %%
channel_stat
# Out:
# {'Channel_name': 'Ericsson',
#  'Subscriber': '42800',
#  'Views': '14147094',
#  'Total_videos': '1207',
#  'playlist_id': 'UUYaPuN9wvwP8gXUUezdvSUQ'}

# %%
channel_data= pd.DataFrame([channel_stat])

# %%
channel_data
# Out:
#   Channel_name Subscriber     Views Total_videos               playlist_id
# 0     Ericsson      42800  14147094         1207  UUYaPuN9wvwP8gXUUezdvSUQ

# %%
channel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Channel_name  1 non-null      object
#  1   Subscriber    1 non-null      object
#  2   Views         1 non-null      object
#  3   Total_videos  1 non-null      object
#  4   playlist_id   1 non-null      object
# dtypes: object(5)
# memory usage: 168.0+ bytes

# %%
channel_data['Subscriber']= pd.to_numeric(channel_data['Subscriber'])
channel_data['Views']= pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']= pd.to_numeric(channel_data['Total_videos'])
channel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Channel_name  1 non-null      object
#  1   Subscriber    1 non-null      int64
#  2   Views         1 non-null      int64
#  3   Total_videos  1 non-null      int64
#  4   playlist_id   1 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 168.0+ bytes

# %% [markdown]
# # Function to get video ids

# %%
playlist_id= channel_data.loc[channel_data['Channel_name']== "Ericsson", 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    request= youtube.playlistItems().list(
        part= 'contentDetails',
        playlistId= playlist_id,
        maxResults=50)
    response= request.execute()

    video_ids= []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

    nextpage_token= response.get('nextPageToken')
    more_pages= True

    while more_pages:
        if nextpage_token is None:
            more_pages= False
        else:
            request= youtube.playlistItems().list(
                        part= 'contentDetails',
                        playlistId= playlist_id,
                        maxResults=50,
                        pageToken= nextpage_token)
            response= request.execute()
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            nextpage_token= response.get('nextPageToken')
            
            
        
    return video_ids

# %%
video_ids=get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['lhPjiVA0_PI',
#  'VZCo1mB-tUI',
#  'Aa5gMnTcRAk',
#  'rJnMDpXbUOA',
#  'Hcv_iCGLbWQ',
#  '-F6JEensl9k',
#  'uU5nbC67Lj4',
#  'e41gzH9ngy4',
#  'Pnyr6JR8zYg',
#  'Nr-30DNBu1M',
#  'DqpYYpdUi9Q',
#  'bBqrNPjz_x8',
#  'xCDUQ31FEZM',
#  'pOE6HSXVooQ',
#  'YEkP2nFgiKU',
#  'Q2NjCIuadgs',
#  '2o7-hVKI_CM',
#  'uUacswxlXxQ',
#  'WWAqfviKREM',
#  'nuVre8WL-CI',
#  'YbAgSpeg58A',
#  '-BrDbOCS8eg',
#  'f8UDLQyj8Jk',
#  'LGpR4EedHSU',
#  '7NUQiH5D6yM',
#  'zGP66JHe5o4',
#  '-JjOaMB1ysM',
#  'iJqDZxIhYu8',
#  'F4Ar_W55wD8',
#  'fpXjGRji6no',
#  'Ka5sZ9_UZJY',
#  'wovVKw0gGCA',
#  '-u27KNr3yVc',
#  '6S0cVASuiB4',
#  'mY3_srEfAf0',
#  '1Mzd0mEr14w',
#  'GPZXoi60wJ4',
#  'o6nNyZ4Fscg',
#  'e4TrRG35mPc',
#  'JSvTeYESHVM',
#  'kKInW6nc0zc',
#  '2YsC59be28o',
#  'CdwyfSipPT8',
#  'JaavlKkpQaA',
#  'Wp8j8pU1G4Q',
#  'Sw8A29183S8',
#  'nK12PPHJJL8',
#  'EwL4dd1Ww0Q',
#  'lEXylzkcZr4',
#  'Ye9lgIUD9tA',
#  'sSDatVSpVnE',
#  'aMAM9lf0Swk',
#  'oyEr1kHIV5A',
#  'VJJ8eT9sBiA',
#  'RVLYQ1EvtuI',
# ...

# %%
def get_video_details(youtube, video_ids):
    all_video= []
    for i in range(0, len(video_ids), 50):
        
        request= youtube.videos().list(
            part= "snippet, statistics",
            id=','.join(video_ids[i:i+50]))
        response= request.execute()

        for video in response['items']:
            video_stats= dict(Title= video['snippet']['title'],
                             Published_date= video['snippet']['publishedAt'],
                             Views= video['statistics']['viewCount'],
                             Likes= video['statistics'].get('likeCount', 0),
                             Comment= video['statistics']['commentCount'])
            all_video.append(video_stats)
    return all_video

# %%
video_detail=get_video_details(youtube, video_ids)

# %%
video_data=pd.DataFrame(video_detail)

# %%
video_data
# Out:
#                                                   Title        Published_date  \
# 0                         Ericsson-díj 2025 – Kis Tamás  2025-07-01T10:22:30Z
# 1          Ericsson KDDI Digital Mirai Lab at EXPO 2025  2025-06-30T04:28:58Z
# 2          Educational Initiatives for Future Workforce  2025-06-30T04:23:03Z
# 3         Cloud Native Infrastructure - Lessons learned  2025-06-27T11:51:18Z
# 4                                   進化した収益化で収益を最大限に引き出す  2025-06-26T05:16:45Z
# ...                                                 ...                   ...
# 1204  Ericsson 5G Core Software Probes & Expert Anal...  2020-02-13T13:30:02Z
# 1205               Ericsson Cloud Native Infrastructure  2020-02-13T13:30:00Z
# 1206  Working with tech at Ericsson Austin Design Ce...  2020-01-21T15:39:45Z
# 1207       Welcome to our Ericsson Austin Design Center  2020-01-21T15:39:23Z
# 1208  Join us live from the Ericsson Studio in Stock...  2019-06-17T14:05:30Z
#
#      Views Likes Comment
# ...

# %%
video_data['Published_date']=pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views']=pd.to_numeric(video_data['Views'])
video_data['Likes']=pd.to_numeric(video_data['Likes'])
video_data['Comment']=pd.to_numeric(video_data['Comment'])
video_data
# Out:
#                                                   Title Published_date  Views  \
# 0                         Ericsson-díj 2025 – Kis Tamás     2025-07-01    247
# 1          Ericsson KDDI Digital Mirai Lab at EXPO 2025     2025-06-30    102
# 2          Educational Initiatives for Future Workforce     2025-06-30     60
# 3         Cloud Native Infrastructure - Lessons learned     2025-06-27    134
# 4                                   進化した収益化で収益を最大限に引き出す     2025-06-26     34
# ...                                                 ...            ...    ...
# 1204  Ericsson 5G Core Software Probes & Expert Anal...     2020-02-13   3372
# 1205               Ericsson Cloud Native Infrastructure     2020-02-13   2799
# 1206  Working with tech at Ericsson Austin Design Ce...     2020-01-21   1546
# 1207       Welcome to our Ericsson Austin Design Center     2020-01-21   2047
# 1208  Join us live from the Ericsson Studio in Stock...     2019-06-17      0
#
#       Likes  Comment
# ...

# %%
video_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           1209 non-null   object
#  1   Published_date  1209 non-null   object
#  2   Views           1209 non-null   int64
#  3   Likes           1209 non-null   int64
#  4   Comment         1209 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 47.4+ KB

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date'])
video_data['Month_Name'] =video_data['Published_date'].dt.month_name()
video_data
# Out:
#                                                   Title Published_date  Views  \
# 0                         Ericsson-díj 2025 – Kis Tamás     2025-07-01    247
# 1          Ericsson KDDI Digital Mirai Lab at EXPO 2025     2025-06-30    102
# 2          Educational Initiatives for Future Workforce     2025-06-30     60
# 3         Cloud Native Infrastructure - Lessons learned     2025-06-27    134
# 4                                   進化した収益化で収益を最大限に引き出す     2025-06-26     34
# ...                                                 ...            ...    ...
# 1204  Ericsson 5G Core Software Probes & Expert Anal...     2020-02-13   3372
# 1205               Ericsson Cloud Native Infrastructure     2020-02-13   2799
# 1206  Working with tech at Ericsson Austin Design Ce...     2020-01-21   1546
# 1207       Welcome to our Ericsson Austin Design Center     2020-01-21   2047
# 1208  Join us live from the Ericsson Studio in Stock...     2019-06-17      0
#
#       Likes  Comment Month_Name
# ...

# %%
video_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           1209 non-null   object
#  1   Published_date  1209 non-null   datetime64[ns]
#  2   Views           1209 non-null   int64
#  3   Likes           1209 non-null   int64
#  4   Comment         1209 non-null   int64
#  5   Month_Name      1209 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 56.8+ KB

# %%
video_data.to_csv("Ericsson Statistics.csv")
channel_data.to_csv("Ericsson Channel.csv")
